# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("rethwsteth-crv-apy-history.csv", index_col="Date")

# %%
fig, ax = plt.subplots(figsize=(10,5))

ax.set_title("rethwsteth Factory Pool CRV APR")
ax.set_ylabel("[%]")
df.plot(use_index=True, ax=ax)
# Out:
# <AxesSubplot:title={'center':'rethwsteth Factory Pool CRV APR'}, xlabel='Date', ylabel='[%]'>
